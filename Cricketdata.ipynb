# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\Dell\Desktop\CricketdataA.xlsx")
df
# Out:
#                    Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0        DG Bradman (AUS)  1928-1948   52    80  10   6996   334  99.94
# 1        PHKD Mendis (SL)  2022-2025   14    24   3   1316  182*  62.66
# 2          AC Voges (AUS)  2015-2016   20    31   7   1485  269*  61.87
# 3         RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97
# 4         RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97
# 5         GA Headley (WI)  1930-1954   22    40   4   2190  270*  60.83
# 6       H Sutcliffe (ENG)  1924-1935   54    84   9   4555   194  60.73
# 7         E Paynter (ENG)  1931-1939   20    31   5   1540   243  59.23
# 8     KF Barrington (ENG)  1955-1968   82   131  15   6806   256  58.67
# 9      KC Sangakkara (SL)  2000-2015  134   233  17  12400   319  57.40
# 10         ED Weekes (WI)  1948-1958   48    81   5   4455   207  58.61
# 11       WR Hammond (ENG)  1927-1947   85   140  16   7249  336*  58.45
# ...

# %%
#rename multiple
df=df.rename(columns={'NO':'Not_Outs','HS':'Highest_Inns_score','BF':'Ball_face','SR':'Batting_strike_rate'})

# %%
df.head()
# Out:
#              Player       Span  Mat  Inns  Not_Outs  Runs Highest_Inns_score  \
# 0  DG Bradman (AUS)  1928-1948   52    80        10  6996                334
# 1  PHKD Mendis (SL)  2022-2025   14    24         3  1316               182*
# 2    AC Voges (AUS)  2015-2016   20    31         7  1485               269*
# 3   RG Pollock (SA)  1963-1970   23    41         4  2256                274
# 4   RG Pollock (SA)  1963-1970   23    41         4  2256                274
#
#      Ave Ball_face Batting_strike_rate  100  50  0    4s  6s
# 0  99.94     9800+                58.6   29  13  7  626+   6
# 1  62.66      2063               63.79    5   5  0   137  24
# 2  61.87      2667               55.68    5   4  2   186   5
# 3  60.97     1707+               54.48    7  11  1  246+  11
# 4  60.97     1707+               54.48    7  11  1  246+  11

# %%
#check nulls
df.isnull().any()
#nan is not shown it only shows real null so better using unique data
# Out:
# Player                 False
# Span                   False
# Mat                    False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_score     False
# Ave                    False
# Ball_face              False
# Batting_strike_rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df = df.replace(['NA', 'N/A', 'null', '-'], np.nan)
df
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_20052\3029729789.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(['NA', 'N/A', 'null', '-'], np.nan)
#                    Player       Span  Mat  Inns  Not_Outs   Runs  \
# 0        DG Bradman (AUS)  1928-1948   52    80        10   6996
# 1        PHKD Mendis (SL)  2022-2025   14    24         3   1316
# 2          AC Voges (AUS)  2015-2016   20    31         7   1485
# 3         RG Pollock (SA)  1963-1970   23    41         4   2256
# 4         RG Pollock (SA)  1963-1970   23    41         4   2256
# 5         GA Headley (WI)  1930-1954   22    40         4   2190
# 6       H Sutcliffe (ENG)  1924-1935   54    84         9   4555
# ...

# %%
#check nulls
df.isnull().any()
#nan is not shown it only shows real null so better using unique data
# Out:
# Player                 False
# Span                   False
# Mat                    False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_score     False
# Ave                    False
# Ball_face               True
# Batting_strike_rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Ball_face'].isna()==1]
# Out:
#              Player       Span  Mat  Inns  Not_Outs  Runs Highest_Inns_score  \
# 10   ED Weekes (WI)  1948-1958   48    81         5  4455                207
# 15  CL Walcott (WI)  1948-1960   44    74         7  3798                220
#
#       Ave Ball_face  Batting_strike_rate  100  50  0    4s  6s
# 10  58.61       NaN                  NaN   15  19  6  258+   2
# 15  56.68       NaN                  NaN   15  14  1  107+  11

# %%
df[df['Batting_strike_rate'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Country, Span, Mat, Inns, Not_Outs, Runs, Highest_Inns_score, Ave, Ball_face, Batting_strike_rate, 100, 50, 0, 4s, 6s, Rookie_Year, Final_Year, Player_name]
# Index: []

# %%
df['Ball_face']=df['Ball_face'].fillna(0)

# %%
df['Batting_strike_rate']=df['Batting_strike_rate'].fillna(0)

# %%
df.head(50)
# Out:
#     Country       Span  Mat  Inns  Not_Outs   Runs  Highest_Inns_score    Ave  \
# 0       AUS  1928-1948   52    80        10   6996                <NA>  99.94
# 1        SL  2022-2025   14    24         3   1316                 182  62.66
# 2       AUS  2015-2016   20    31         7   1485                 269  61.87
# 3        SA  1963-1970   23    41         4   2256                <NA>  60.97
# 4        SA  1963-1970   23    41         4   2256                <NA>  60.97
# 5        WI  1930-1954   22    40         4   2190                 270  60.83
# 6       ENG  1924-1935   54    84         9   4555                <NA>  60.73
# 7       ENG  1931-1939   20    31         5   1540                <NA>  59.23
# 8       ENG  1955-1968   82   131        15   6806                <NA>  58.67
# 9        SL  2000-2015  134   233        17  12400                <NA>  57.40
# 10       WI  1948-1958   48    81         5   4455                <NA>  58.61
# ...

# %%
#drop dublicate
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# dtype: bool

# %%
#remove dublicate  check
df[df['Player'].duplicated()==1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\jppt\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Player'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[186], line 2
#       1 #remove dublicate  check
# ...

# %%
df.drop_duplicates()
# Out:
#     Country       Span  Mat  Inns  Not_Outs   Runs  Highest_Inns_score    Ave  \
# 0       AUS  1928-1948   52    80        10   6996                <NA>  99.94
# 1        SL  2022-2025   14    24         3   1316                 182  62.66
# 2       AUS  2015-2016   20    31         7   1485                 269  61.87
# 3        SA  1963-1970   23    41         4   2256                <NA>  60.97
# 5        WI  1930-1954   22    40         4   2190                 270  60.83
# 6       ENG  1924-1935   54    84         9   4555                <NA>  60.73
# 7       ENG  1931-1939   20    31         5   1540                <NA>  59.23
# 8       ENG  1955-1968   82   131        15   6806                <NA>  58.67
# 9        SL  2000-2015  134   233        17  12400                <NA>  57.40
# 10       WI  1948-1958   48    81         5   4455                <NA>  58.61
# 11      ENG  1927-1947   85   140        16   7249                 336  58.45
# ...

# %%
#start span into start and end date
df['Span'].str.split(pat='-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2025]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1963, 1970]
# 5     [1930, 1954]
# 6     [1924, 1935]
# 7     [1931, 1939]
# 8     [1955, 1968]
# 9     [2000, 2015]
# 10    [1948, 1958]
# 11    [1927, 1947]
# 12    [1954, 1974]
# 13    [2000, 2015]
# 14    [1908, 1930]
# 15    [1948, 1960]
# 16    [1937, 1955]
# 17    [2010, 2026]
# 18    [1995, 2013]
# 19    [1921, 1929]
# 20    [2022, 2026]
# 21    [2010, 2025]
# 22    [1968, 1973]
# 23    [1993, 1995]
# 24    [1970, 1984]
# 25    [1935, 1951]
# 26    [1989, 2013]
# 27    [1990, 2006]
# 28    [1976, 1993]
# 29    [1996, 2012]
# 30    [1998, 2010]
# 31    [2000, 2017]
# 32    [1995, 2012]
# 33    [1920, 1929]
# 34    [1992, 2002]
# 35    [2005, 2013]
# 36    [1994, 2015]
# 37    [1971, 1987]
# 38    [2012, 2026]
# 39    [1985, 2004]
# 40    [1994, 2009]
# 41    [2004, 2018]
# 42    [1978, 1994]
# Name: Span, dtype: object

# %%
df['Span'].str.split(pat='-').str[0]
# Out:
# 0     1928
# 1     2022
# 2     2015
# 3     1963
# 4     1963
# 5     1930
# 6     1924
# 7     1931
# 8     1955
# 9     2000
# 10    1948
# 11    1927
# 12    1954
# 13    2000
# 14    1908
# 15    1948
# 16    1937
# 17    2010
# 18    1995
# 19    1921
# 20    2022
# 21    2010
# 22    1968
# 23    1993
# 24    1970
# 25    1935
# 26    1989
# 27    1990
# 28    1976
# 29    1996
# 30    1998
# 31    2000
# 32    1995
# 33    1920
# 34    1992
# 35    2005
# 36    1994
# 37    1971
# 38    2012
# 39    1985
# 40    1994
# 41    2004
# 42    1978
# Name: Span, dtype: object

# %%
df['Rookie_Year']=df['Span'].str.split(pat='-').str[0]
df['Final_Year']=df['Span'].str.split(pat='-').str[1]

# %%
df['Player'].str.split(pat='(')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\jppt\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Player'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[191], line 1
# ----> 1 df['Player'].str.split(pat='(')
#
# ...

# %%
df['Country']=df['Player'].str.split(pat='(').str[1]
df.head()
# Out:
#              Player       Span  Mat  Inns  Not_Outs  Runs Highest_Inns_score  \
# 0  DG Bradman (AUS)  1928-1948   52    80        10  6996                334
# 1  PHKD Mendis (SL)  2022-2025   14    24         3  1316               182*
# 2    AC Voges (AUS)  2015-2016   20    31         7  1485               269*
# 3   RG Pollock (SA)  1963-1970   23    41         4  2256                274
# 4   RG Pollock (SA)  1963-1970   23    41         4  2256                274
#
#      Ave Ball_face  Batting_strike_rate  100  50  0    4s  6s Rookie_Year  \
# 0  99.94     9800+                58.60   29  13  7  626+   6        1928
# 1  62.66      2063                63.79    5   5  0   137  24        2022
# 2  61.87      2667                55.68    5   4  2   186   5        2015
# 3  60.97     1707+                54.48    7  11  1  246+  11        1963
# 4  60.97     1707+                54.48    7  11  1  246+  11        1963
#
#   Final_Year Country
# 0       1948    AUS)
# ...

# %%
df['Country']=df['Player'].str.split(pat='(').str[1]
df.head()
# Out:
#              Player       Span  Mat  Inns  Not_Outs  Runs Highest_Inns_score  \
# 0  DG Bradman (AUS)  1928-1948   52    80        10  6996                334
# 1  PHKD Mendis (SL)  2022-2025   14    24         3  1316               182*
# 2    AC Voges (AUS)  2015-2016   20    31         7  1485               269*
# 3   RG Pollock (SA)  1963-1970   23    41         4  2256                274
# 4   RG Pollock (SA)  1963-1970   23    41         4  2256                274
#
#      Ave Ball_face  Batting_strike_rate  100  50  0    4s  6s Rookie_Year  \
# 0  99.94     9800+                58.60   29  13  7  626+   6        1928
# 1  62.66      2063                63.79    5   5  0   137  24        2022
# 2  61.87      2667                55.68    5   4  2   186   5        2015
# 3  60.97     1707+                54.48    7  11  1  246+  11        1963
# 4  60.97     1707+                54.48    7  11  1  246+  11        1963
#
#   Final_Year Country
# 0       1948    AUS)
# ...

# %%
df['Player_name']=df['Player'].str.split(pat='(').str[0]
df
# Out:
#                    Player       Span  Mat  Inns  Not_Outs   Runs  \
# 0        DG Bradman (AUS)  1928-1948   52    80        10   6996
# 1        PHKD Mendis (SL)  2022-2025   14    24         3   1316
# 2          AC Voges (AUS)  2015-2016   20    31         7   1485
# 3         RG Pollock (SA)  1963-1970   23    41         4   2256
# 4         RG Pollock (SA)  1963-1970   23    41         4   2256
# 5         GA Headley (WI)  1930-1954   22    40         4   2190
# 6       H Sutcliffe (ENG)  1924-1935   54    84         9   4555
# 7         E Paynter (ENG)  1931-1939   20    31         5   1540
# 8     KF Barrington (ENG)  1955-1968   82   131        15   6806
# 9      KC Sangakkara (SL)  2000-2015  134   233        17  12400
# 10         ED Weekes (WI)  1948-1958   48    81         5   4455
# 11       WR Hammond (ENG)  1927-1947   85   140        16   7249
# 12         GS Sobers (WI)  1954-1974   93   160        21   8032
# ...

# %%
#remove rightstrip
df['Country'] = df['Country'].str.rstrip(')')
df
# Out:
#                    Player       Span  Mat  Inns  Not_Outs   Runs  \
# 0        DG Bradman (AUS)  1928-1948   52    80        10   6996
# 1        PHKD Mendis (SL)  2022-2025   14    24         3   1316
# 2          AC Voges (AUS)  2015-2016   20    31         7   1485
# 3         RG Pollock (SA)  1963-1970   23    41         4   2256
# 4         RG Pollock (SA)  1963-1970   23    41         4   2256
# 5         GA Headley (WI)  1930-1954   22    40         4   2190
# 6       H Sutcliffe (ENG)  1924-1935   54    84         9   4555
# 7         E Paynter (ENG)  1931-1939   20    31         5   1540
# 8     KF Barrington (ENG)  1955-1968   82   131        15   6806
# 9      KC Sangakkara (SL)  2000-2015  134   233        17  12400
# 10         ED Weekes (WI)  1948-1958   48    81         5   4455
# 11       WR Hammond (ENG)  1927-1947   85   140        16   7249
# 12         GS Sobers (WI)  1954-1974   93   160        21   8032
# ...

# %%
df = df.drop('Player', axis=1)
df
# Out:
#          Span  Mat  Inns  Not_Outs   Runs Highest_Inns_score    Ave Ball_face  \
# 0   1928-1948   52    80        10   6996                334  99.94     9800+
# 1   2022-2025   14    24         3   1316               182*  62.66      2063
# 2   2015-2016   20    31         7   1485               269*  61.87      2667
# 3   1963-1970   23    41         4   2256                274  60.97     1707+
# 4   1963-1970   23    41         4   2256                274  60.97     1707+
# 5   1930-1954   22    40         4   2190               270*  60.83      416+
# 6   1924-1935   54    84         9   4555                194  60.73     6558+
# 7   1931-1939   20    31         5   1540                243  59.23     1288+
# 8   1955-1968   82   131        15   6806                256  58.67     4957+
# 9   2000-2015  134   233        17  12400                319  57.40     22882
# 10  1948-1958   48    81         5   4455                207  58.61         0
# ...

# %%
# Example: move 'Country' column to first position
col = df.pop('Country')        # removes 'Country' and keeps the data
df.insert(0, 'Country', col)
df
# Out:
#     Country       Span  Mat  Inns  Not_Outs   Runs Highest_Inns_score    Ave  \
# 0       AUS  1928-1948   52    80        10   6996                334  99.94
# 1        SL  2022-2025   14    24         3   1316               182*  62.66
# 2       AUS  2015-2016   20    31         7   1485               269*  61.87
# 3        SA  1963-1970   23    41         4   2256                274  60.97
# 4        SA  1963-1970   23    41         4   2256                274  60.97
# 5        WI  1930-1954   22    40         4   2190               270*  60.83
# 6       ENG  1924-1935   54    84         9   4555                194  60.73
# 7       ENG  1931-1939   20    31         5   1540                243  59.23
# 8       ENG  1955-1968   82   131        15   6806                256  58.67
# 9        SL  2000-2015  134   233        17  12400                319  57.40
# 10       WI  1948-1958   48    81         5   4455                207  58.61
# ...

# %%
df.dtypes
# Out:
# Country                 object
# Span                    object
# Mat                      int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_score      object
# Ave                    float64
# Ball_face               object
# Batting_strike_rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Player_name             object
# dtype: object

# %%
df.isnull().any()
# Out:
# Country                False
# Span                   False
# Mat                    False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_score     False
# Ave                    False
# Ball_face              False
# Batting_strike_rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Player_name            False
# dtype: bool

# %%
print(df['Highest_Inns_score'].head(10))
print(df['Highest_Inns_score'].isna().sum())
# Out:
# 0    NaN
# 1    182
# 2    269
# 3    NaN
# 4    NaN
# 5    270
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# Name: Highest_Inns_score, dtype: object
# 29

# %%
df['Highest_Inns_score'] = df['Highest_Inns_score'].str.replace(r'\*', '', regex=True)
